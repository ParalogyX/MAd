# %%
import importlib
from datetime import datetime, timezone

# Reload local package modules so this notebook picks up provider changes
# without requiring a full kernel restart.
for module_name in (
    "investment_adviser.config",
    "investment_adviser.providers.symbols",
    "investment_adviser.providers.libertex",
    "investment_adviser.providers.fallback",
    "investment_adviser",
):
    module = importlib.import_module(module_name)
    importlib.reload(module)

from investment_adviser import (
    find_libertex_instruments,
    load_symbol_data,
    perform_technical_analysis,
    perform_candle_analysis,
    perform_symbol_sentiment_analysis,
)
from investment_adviser.exceptions import DataProviderError

# %%
tickers = find_libertex_instruments()

one_ticker = tickers[1]

# %%
one_ticker
# Out:
# 'AAPL'

# %%
data = load_symbol_data(one_ticker, "1d", datetime(2026, 1, 1, 0, 0), datetime(2026, 6, 1))

# %%
data
# Out:
# Price                 timestamp        open        high         low  \
# 0     2026-01-02 00:00:00+00:00  272.260010  277.839996  269.000000
# 1     2026-01-05 00:00:00+00:00  270.640015  271.510010  266.140015
# 2     2026-01-06 00:00:00+00:00  267.000000  267.549988  262.119995
# 3     2026-01-07 00:00:00+00:00  263.200012  263.679993  259.809998
# 4     2026-01-08 00:00:00+00:00  257.019989  259.290009  255.699997
# ..                          ...         ...         ...         ...
# 97    2026-05-22 00:00:00+00:00  306.119995  311.399994  305.839996
# 98    2026-05-26 00:00:00+00:00  309.559998  311.820007  307.670013
# 99    2026-05-27 00:00:00+00:00  308.329987  313.260010  308.299988
# 100   2026-05-28 00:00:00+00:00  310.679993  312.799988  309.570007
# 101   2026-05-29 00:00:00+00:00  311.779999  315.000000  309.529999
#
# Price       close    volume
# 0      271.010010  37838100
# 1      267.260010  45647200
# 2      262.359985  52352100
# 3      260.329987  48309800
# 4      259.040009  50419300
# ..            ...       ...
# 97     308.820007  43670200
# 98     308.329987  48000500
# 99     310.850006  50430900
# 100    312.510010  48220400
# 101    312.059998  70026800
#
# [102 rows x 6 columns]

# %%
perform_technical_analysis(data)
# Out:
#             indicator_name  indicator_value indicator_category  \
# 0                   SMA 20     2.975415e+02              trend
# 1                   SMA 50     2.752846e+02              trend
# 2                   EMA 20     2.978874e+02              trend
# 3                   EMA 50     2.832571e+02              trend
# 4                   RSI 14     7.871412e+01           momentum
# 5                     MACD     1.039272e+01           momentum
# 6              MACD signal     9.778779e+00           momentum
# 7           MACD histogram     6.139431e-01           momentum
# 8    Bollinger Bands upper     3.180682e+02         volatility
# 9   Bollinger Bands middle     2.975415e+02         volatility
# 10   Bollinger Bands lower     2.770148e+02         volatility
# 11                  ATR 14     4.965718e+00         volatility
# 12           Stochastic %K     8.813079e+01           momentum
# 13           Stochastic %D     9.204545e+01           momentum
# 14                  ADX 14     4.394408e+01     trend_strength
# 15            Latest close     3.120600e+02              price
# 16           Latest volume     7.002680e+07             volume
#
#               signal                                        description
# 0      bullish trend                   20-period simple moving average.
# 1      bullish trend                   50-period simple moving average.
# 2            neutral              20-period exponential moving average.
# 3            neutral              50-period exponential moving average.
# 4         overbought                 14-period relative strength index.
# 5   bullish momentum      MACD line using 12-period and 26-period EMAs.
# 6   bullish momentum                     9-period EMA of the MACD line.
# 7            neutral           Difference between MACD and MACD signal.
# 8            neutral  Upper Bollinger Band: SMA 20 plus two standard...
# 9            neutral                     Middle Bollinger Band: SMA 20.
# 10           neutral  Lower Bollinger Band: SMA 20 minus two standar...
# 11           neutral                      14-period average true range.
# 12        overbought                14-period stochastic oscillator %K.
# 13        overbought                 3-period average of stochastic %K.
# 14      strong trend               14-period average directional index.
# 15           neutral              Latest close price in the input data.
# 16           neutral                   Latest volume in the input data.

# %%
perform_candle_analysis(data)
# Out:
#                    timestamp        candle_type direction  confidence
# 0  2026-01-07 00:00:00+00:00  three black crows   bearish        0.70
# 1  2026-01-09 00:00:00+00:00               doji   neutral        0.80
# 2  2026-01-12 00:00:00+00:00             hammer   bullish        0.65
# 3  2026-01-14 00:00:00+00:00               doji   neutral        0.80
# 4  2026-01-15 00:00:00+00:00  bearish engulfing   bearish        0.80
# 5  2026-01-20 00:00:00+00:00  three black crows   bearish        0.70
# 6  2026-01-22 00:00:00+00:00    inverted hammer   bullish        0.55
# 7  2026-01-27 00:00:00+00:00      shooting star   bearish        0.65
# 8  2026-01-29 00:00:00+00:00               doji   neutral        0.80
# 9  2026-02-03 00:00:00+00:00               doji   neutral        0.80
# 10 2026-02-06 00:00:00+00:00      shooting star   bearish        0.65
# 11 2026-02-11 00:00:00+00:00    inverted hammer   bullish        0.55
# 12 2026-02-12 00:00:00+00:00  bearish engulfing   bearish        0.80
# 13 2026-02-19 00:00:00+00:00       evening star   bearish        0.75
# 14 2026-02-20 00:00:00+00:00  bullish engulfing   bullish        0.80
# 15 2026-02-26 00:00:00+00:00   dark cloud cover   bearish        0.65
# 16 2026-03-03 00:00:00+00:00               doji   neutral        0.80
# 17 2026-03-04 00:00:00+00:00  bearish engulfing   bearish        0.80
# 18 2026-03-06 00:00:00+00:00             hammer   bullish        0.65
# 19 2026-03-09 00:00:00+00:00  bullish engulfing   bullish        0.80
# 20 2026-03-12 00:00:00+00:00       evening star   bearish        0.75
# 21 2026-03-19 00:00:00+00:00               doji   neutral        0.80
# 22 2026-03-20 00:00:00+00:00               doji   neutral        0.80
# 23 2026-03-24 00:00:00+00:00      shooting star   bearish        0.65
# 24 2026-03-27 00:00:00+00:00  bearish engulfing   bearish        0.80
# 25 2026-04-02 00:00:00+00:00        hanging man   bearish        0.55
# 26 2026-04-07 00:00:00+00:00        hanging man   bearish        0.55
# 27 2026-04-13 00:00:00+00:00        hanging man   bearish        0.55
# 28 2026-04-14 00:00:00+00:00               doji   neutral        0.80
# 29 2026-04-15 00:00:00+00:00  bullish engulfing   bullish        0.80
# 30 2026-05-01 00:00:00+00:00      shooting star   bearish        0.65
# 31 2026-05-15 00:00:00+00:00  bullish engulfing   bullish        0.80
# 32 2026-05-18 00:00:00+00:00  bearish engulfing   bearish        0.80
# 33 2026-05-27 00:00:00+00:00  bullish engulfing   bullish        0.80
# 34 2026-05-29 00:00:00+00:00               doji   neutral        0.80

# %%
perform_symbol_sentiment_analysis(one_ticker)
# Out:
#   symbol  sentiment_score  confidence  source_count  positive_count  \
# 0   AAPL               -7      0.4167            30               0
#
#    neutral_count  negative_count                        timestamp
# 0             28               2 2026-06-10 10:51:29.971455+00:00
